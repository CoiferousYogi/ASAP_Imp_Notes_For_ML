# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Set global styles for plots
plt.style.use('ggplot')
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

# Generate sample data
np.random.seed(0)
num_employees = 1000

departments = np.random.choice(['Finance', 'Health', 'Education', 'Transport'], num_employees)
salaries = np.random.normal(loc=50000, scale=10000, size=num_employees)
years_of_service = np.random.randint(1, 30, size=num_employees)
ages = np.random.randint(22, 65, size=num_employees)
genders = np.random.choice(['Male', 'Female'], num_employees)

# Create DataFrame
data = pd.DataFrame({
    'Department': departments,
    'Salary': salaries,
    'Years of Service': years_of_service,
    'Age': ages,
    'Gender': genders
})

# %%
# Plot 1: Distribution of salaries
plt.figure(figsize=(8, 6))
data['Salary'].plot(kind='hist')
plt.xlabel('Salary')
plt.title('Salary Distribution')
# plt.show()
# Out:
# Text(0.5, 1.0, 'Salary Distribution')

# %%
# Plot 2: Distribution of years of service
plt.figure(figsize=(8, 6))
data['Years of Service'].plot(kind='hist')
plt.xlabel('Years of Service')
plt.title('Years of Service Distribution')
plt.show()

# %%
# Plot 3: Boxplot of salaries by department
plt.figure(figsize=(8, 6))
data.boxplot(column='Salary', by='Department')
plt.title('Salary Distribution by Department')
plt.ylabel('Salary')
plt.xlabel('Department')
plt.tight_layout()
plt.show()

# %%
# Plot 4: Bar plot of average salary by department
plt.figure(figsize=(8, 6))
data.groupby('Department')['Salary'].mean().plot(kind='bar', color='skyblue')
plt.title('Average Salary by Department')
plt.ylabel('Average Salary')
plt.xlabel('Department')
plt.show()

# %%
# Plot 5: Pie chart of gender distribution
plt.figure(figsize=(8, 6))
data['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightskyblue'])
plt.title('Gender Distribution')
plt.show()

# %%
# Plot 6: Scatter plot of age vs. years of service
plt.figure(figsize=(8, 6))
plt.scatter(data['Age'], data['Years of Service'], alpha=0.5)
plt.title('Age vs. Years of Service')
plt.xlabel('Age')
plt.ylabel('Years of Service')
plt.show()

# %%
# Plot 7: Bar plot of number of employees in each department
plt.figure(figsize=(8, 6))
data['Department'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('Number of Employees in Each Department')
plt.ylabel('Number of Employees')
plt.xlabel('Department')
plt.show()

# %%
# Plot 8: Boxplot of salaries by gender
plt.figure(figsize=(8, 6))
data.boxplot(column='Salary', by='Gender')
plt.title('Salary Distribution by Gender')
plt.ylabel('Salary')
plt.xlabel('Gender')
plt.tight_layout()
plt.show()

# %%
# Plot 9: Histogram of ages
plt.figure(figsize=(8, 6))
data['Age'].plot(kind='hist')
plt.xlabel('Age')
plt.title('Age Distribution')
plt.show()

# %%
# Plot 10: Boxplot of years of service by department
plt.figure(figsize=(8, 6))
data.boxplot(column='Years of Service', by='Department')
plt.title('Years of Service Distribution by Department')
plt.ylabel('Years of Service')
plt.xlabel('Department')
plt.tight_layout()
plt.show()

# %%
# Plot 11: Scatter plot of salary vs. years of service
plt.figure(figsize=(8, 6))
plt.scatter(data['Salary'], data['Years of Service'], alpha=0.5)
plt.title('Salary vs. Years of Service')
plt.xlabel('Salary')
plt.ylabel('Years of Service')
plt.show()

# %%
# Plot 12: Boxplot of ages by gender
plt.figure(figsize=(8, 6))
data.boxplot(column='Age', by='Gender')
plt.title('Age Distribution by Gender')
plt.ylabel('Age')
plt.xlabel('Gender')
plt.tight_layout()
plt.show()

# %%
# Plot 13: Bar plot of number of employees by gender
plt.figure(figsize=(8, 6))
data['Gender'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('Number of Employees by Gender')
plt.ylabel('Number of Employees')
plt.xlabel('Gender')
plt.show()

# %%
# Plot 14: Boxplot of ages by department
plt.figure(figsize=(8, 6))
data.boxplot(column='Age', by='Department')
plt.title('Age Distribution by Department')
plt.ylabel('Age')
plt.xlabel('Department')
plt.tight_layout()
plt.show()

# %%
# Plot 15: Histogram of years of service
plt.figure(figsize=(8, 6))
data['Years of Service'].plot(kind='hist')
plt.xlabel('Years of Service')
plt.title('Years of Service Distribution')
plt.show()

# %%
# Plot 16: Scatter plot of salary vs. age
plt.figure(figsize=(8, 6))
plt.scatter(data['Salary'], data['Age'], alpha=0.5)
plt.title('Salary vs. Age')
plt.xlabel('Salary')
plt.ylabel('Age')
plt.show()

# %%
# Create subplots for multiple plots
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20, 20))


# Plot 1: Distribution of salaries
data['Salary'].plot(kind='hist', ax=axes[0, 0], title='Salary Distribution')
axes[0, 0].set_xlabel('Salary')

# Plot 2: Distribution of years of service
data['Years of Service'].plot(kind='hist', ax=axes[0, 1], title='Years of Service Distribution')
axes[0, 1].set_xlabel('Years of Service')

# Plot 3: Boxplot of salaries by department
data.boxplot(column='Salary', by='Department', ax=axes[0, 2])
axes[0, 2].set_title('Salary Distribution by Department')
axes[0, 2].set_ylabel('Salary')
axes[0, 2].set_xlabel('Department')

# Plot 4: Bar plot of average salary by department
data.groupby('Department')['Salary'].mean().plot(kind='bar', ax=axes[0, 3], color='skyblue')
axes[0, 3].set_title('Average Salary by Department')
axes[0, 3].set_ylabel('Average Salary')
axes[0, 3].set_xlabel('Department')

# Plot 5: Pie chart of gender distribution
data['Gender'].value_counts().plot(kind='pie', ax=axes[1, 0], autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightskyblue'])
axes[1, 0].set_title('Gender Distribution')

# Plot 6: Scatter plot of age vs. years of service
data.plot(kind='scatter', x='Age', y='Years of Service', ax=axes[1, 1], alpha=0.5)
axes[1, 1].set_title('Age vs. Years of Service')
axes[1, 1].set_xlabel('Age')
axes[1, 1].set_ylabel('Years of Service')

# Plot 7: Bar plot of number of employees in each department
data['Department'].value_counts().plot(kind='bar', ax=axes[1, 2], color='lightgreen')
axes[1, 2].set_title('Number of Employees in Each Department')
axes[1, 2].set_ylabel('Number of Employees')
axes[1, 2].set_xlabel('Department')

# Plot 8: Boxplot of salaries by gender
data.boxplot(column='Salary', by='Gender', ax=axes[1, 3])
axes[1, 3].set_title('Salary Distribution by Gender')
axes[1, 3].set_ylabel('Salary')
axes[1, 3].set_xlabel('Gender')

# Plot 9: Histogram of ages
data['Age'].plot(kind='hist', ax=axes[2, 0], title='Age Distribution')
axes[2, 0].set_xlabel('Age')

# Plot 10: Boxplot of years of service by department
data.boxplot(column='Years of Service', by='Department', ax=axes[2, 1])
axes[2, 1].set_title('Years of Service Distribution by Department')
axes[2, 1].set_ylabel('Years of Service')
axes[2, 1].set_xlabel('Department')

# Plot 11: Scatter plot of salary vs. years of service
data.plot(kind='scatter', x='Salary', y='Years of Service', ax=axes[2, 2], alpha=0.5)
axes[2, 2].set_title('Salary vs. Years of Service')
axes[2, 2].set_xlabel('Salary')
axes[2, 2].set_ylabel('Years of Service')

# Plot 12: Boxplot of ages by gender
data.boxplot(column='Age', by='Gender', ax=axes[2, 3])
axes[2, 3].set_title('Age Distribution by Gender')
axes[2, 3].set_ylabel('Age')
axes[2, 3].set_xlabel('Gender')

# Plot 13: Bar plot of number of employees by gender
data['Gender'].value_counts().plot(kind='bar', ax=axes[3, 0], color='lightcoral')
axes[3, 0].set_title('Number of Employees by Gender')
axes[3, 0].set_ylabel('Number of Employees')
axes[3, 0].set_xlabel('Gender')

# Plot 14: Boxplot of ages by department
data.boxplot(column='Age', by='Department', ax=axes[3, 1])
axes[3, 1].set_title('Age Distribution by Department')
axes[3, 1].set_ylabel('Age')
axes[3, 1].set_xlabel('Department')

# Plot 15: Histogram of years of service
data['Years of Service'].plot(kind='hist', ax=axes[3, 2], title='Years of Service Distribution')
axes[3, 2].set_xlabel('Years of Service')

# Plot 16: Boxplot of ages by department
data.boxplot(column='Age', by='Department', ax=axes[3, 3])
axes[3, 3].set_title('Age Distribution by Department')
axes[3, 3].set_ylabel('Age')
axes[3, 3].set_xlabel('Department')

# Plot 17: Scatter plot of salary vs. age
data.plot(kind='scatter', x='Salary', y='Age', ax=axes[4, 0], alpha=0.5)
axes[4, 0].set_title('Salary vs. Age')
axes[4, 0].set_xlabel('Salary')
axes[4, 0].set_ylabel('Age')

# Remove empty subplots
fig.delaxes(axes[4, 1])
fig.delaxes(axes[4, 2])
fig.delaxes(axes[4, 3])

# Adjust layout
plt.tight_layout()

# Show plots
plt.show()

# %%
import numpy as np
import pandas as pd

# Set random seed for reproducibility
np.random.seed(0)

# Number of samples
num_samples = 1000

# Generate random data for features
years_of_experience = np.random.randint(1, 30, size=num_samples)
age = np.random.randint(22, 65, size=num_samples)
education_level = np.random.randint(1, 5, size=num_samples)  # Assuming 1=High School, 2=Bachelor's, 3=Master's, 4=PhD
noise = np.random.normal(loc=0, scale=5000, size=num_samples)

# Generate salary data based on other features with some noise
salary = 30000 + (years_of_experience * 500) + (age * 200) + (education_level * 3000) + noise

# Create DataFrame
data = pd.DataFrame({
    'Years of Experience': years_of_experience,
    'Age': age,
    'Education Level': education_level,
    'Salary': salary
})

# %%
import matplotlib.pyplot as plt

# Calculate correlation matrix
correlation_matrix = data.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')

# Add annotations
for i in range(len(correlation_matrix)):
    for j in range(len(correlation_matrix)):
        plt.text(j, i, f'{correlation_matrix.iloc[i, j]:.2f}', ha='center', va='center', color='black')
        
        
plt.colorbar(label='Correlation')
plt.title('Correlation Heatmap')
plt.xticks(range(len(correlation_matrix)), correlation_matrix.columns, rotation=45)
plt.yticks(range(len(correlation_matrix)), correlation_matrix.columns)
plt.tight_layout()
plt.grid(False)
plt.show()
